# %% [markdown]
# ### Basic library imports

# %%
import os
import pandas as pd

# %% [markdown]
# ### Read Dataset

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
DATASET_FOLDER = '/content/sample_data/Images'
train = pd.read_csv(os.path.join(DATASET_FOLDER, '/content/train.csv'))
test = pd.read_csv(os.path.join(DATASET_FOLDER, '/content/test.csv'))

# %% [markdown]
# ### Run Sanity check using src/sanity.py

# %%
# !python sanity.py --test_filename ../dataset/sample_test.csv --output_filename ../dataset/sample_test_out.csv

# %%
# !python sanity.py --test_filename ../dataset/sample_test.csv --output_filename ../dataset/sample_test_out_fail.csv

# %% [markdown]
# ### Download images

# %%
# %pip install constants
import re
import constants
import os
import requests
import pandas as pd
import multiprocessing
import time
from time import time as timer
from tqdm import tqdm
import numpy as np
from pathlib import Path
from functools import partial
import requests
import urllib
from PIL import Image

def common_mistake(unit):
    if unit in constants.allowed_units:
        return unit
    if unit.replace('ter', 'tre') in constants.allowed_units:
        return unit.replace('ter', 'tre')
    if unit.replace('feet', 'foot') in constants.allowed_units:
        return unit.replace('feet', 'foot')
    return unit

def parse_string(s):
    s_stripped = "" if s==None or str(s)=='nan' else s.strip()
    if s_stripped == "":
        return None, None
    pattern = re.compile(r'^-?\d+(\.\d+)?\s+[a-zA-Z\s]+$')
    if not pattern.match(s_stripped):
        raise ValueError("Invalid format in {}".format(s))
    parts = s_stripped.split(maxsplit=1)
    number = float(parts[0])
    unit = common_mistake(parts[1])
    if unit not in constants.allowed_units:
        raise ValueError("Invalid unit [{}] found in {}. Allowed units: {}".format(
            unit, s, constants.allowed_units))
    return number, unit


def create_placeholder_image(image_save_path):
    try:
        placeholder_image = Image.new('RGB', (100, 100), color='black')
        placeholder_image.save(image_save_path)
    except Exception as e:
        return

def download_image(image_link, save_folder, retries=3, delay=3):
    if not isinstance(image_link, str):
        return

    filename = Path(image_link).name
    image_save_path = os.path.join(save_folder, filename)

    if os.path.exists(image_save_path):
        return

    for _ in range(retries):
        try:
            urllib.request.urlretrieve(image_link, image_save_path)
            return
        except:
            time.sleep(delay)

    create_placeholder_image(image_save_path) #Create a black placeholder image for invalid links/images

def download_images(image_links, download_folder, allow_multiprocessing=True):
    if not os.path.exists(download_folder):
        os.makedirs(download_folder)

    if allow_multiprocessing:
        download_image_partial = partial(
            download_image, save_folder=download_folder, retries=3, delay=3)

        with multiprocessing.Pool(64) as pool:
            list(tqdm(pool.imap(download_image_partial, image_links), total=len(image_links)))
            pool.close()
            pool.join()
    else:
        for image_link in tqdm(image_links, total=len(image_links)):
            download_image(image_link, save_folder=download_folder, retries=3, delay=3)

download_images(train['image_link'], '/content/sample_data/Images')
#Image path : /content/sample_data/Images
# Out:
# Requirement already satisfied: constants in /usr/local/lib/python3.10/dist-packages (0.6.0)
# 100%|██████████| 263859/263859 [31:17<00:00, 140.57it/s]

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
import numpy as np
import pandas as pd
import os
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import re

# Load pre-trained ResNet50 model without the top layers
base_model = ResNet50(weights='imagenet', include_top=False)

# Add custom layers for entity value extraction
image_input = base_model.input
x = base_model.output
x = GlobalAveragePooling2D()(x)

# Add numeric value branch (output is a single value)
numeric_output = Dense(1024, activation='relu')(x)
numeric_output = Dense(1, activation='linear', name='numeric_output')(numeric_output)

# Add unit output branch (output is a categorical class)
unit_output = Dense(1024, activation='relu')(x)
unit_output = Dense(50, activation='softmax', name='unit_output')(unit_output)  # 50 unit categories (example size)

# Create the final model
model = Model(inputs=image_input, outputs=[numeric_output, unit_output])

# Freeze the ResNet base model layers
for layer in base_model.layers:
    layer.trainable = False

# Compile the model with two losses (MSE for numeric and categorical cross-entropy for units)
model.compile(optimizer='adam', loss={'numeric_output': 'mean_squared_error', 'unit_output': 'categorical_crossentropy'})

# Load your CSV data
data = pd.read_csv('train.csv')

# Lists to store training data
x_train = []
y_train_numeric = []
y_train_units = []

# Dictionary to map various unit names to a standardized unit
unit_mapping = {
    'cm': 'centimeter', 'centimetres': 'centimeter', 'centimeters': 'centimeter', 'centimetre': 'centimeter',
    'in': 'inch', 'inch': 'inch', 'inches': 'inch',
    'mm': 'millimeter', 'millimetres': 'millimeter', 'millimeters': 'millimeter',
    'm': 'meter', 'metres': 'meter', 'meters': 'meter', 'metre': 'meter',
    'ft': 'foot', 'foot': 'foot', 'feet': 'foot',
    'yd': 'yard', 'yards': 'yard', 'yard': 'yard',
    'g': 'gram', 'grams': 'gram', 'gram': 'gram',
    'kg': 'kilogram', 'kgs': 'kilogram', 'kilograms': 'kilogram', 'kilogram': 'kilogram',
    'mg': 'milligram', 'milligrams': 'milligram', 'milligram': 'milligram',
    'lb': 'pound', 'lbs': 'pound', 'pounds': 'pound', 'pound': 'pound',
    'oz': 'ounce', 'ounces': 'ounce', 'ounce': 'ounce',
    't': 'ton', 'tons': 'ton', 'tonnes': 'ton', 'tonne': 'ton',
    'ml': 'millilitre', 'milliliters': 'millilitre', 'millilitres': 'millilitre',
    'l': 'litre', 'liters': 'litre', 'litres': 'litre',
    'cl': 'centilitre', 'centiliters': 'centilitre', 'centilitres': 'centilitre',
    'dl': 'decilitre', 'deciliters': 'decilitre', 'decilitres': 'decilitre',
    'kv': 'kilovolt', 'kilovolts': 'kilovolt',
    'mv': 'millivolt', 'millivolts': 'millivolt',
    'w': 'watt', 'watts': 'watt',
    'kw': 'kilowatt', 'kilowatts': 'kilowatt'
}

# Function to map units to standardized form
def map_unit(unit):
    return unit_mapping.get(unit.lower(), 'unknown')

# Function to preprocess the image
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img_array

# Function to parse numeric values and units from the 'entity_value' column
def parse_value_and_unit(value):
    try:
        # Handle ranges and lists
        if '[' in value and ']' in value:
            value = re.sub(r'\[|\]', '', value)  # Remove brackets
            values = [float(v.strip()) for v in value.split(',')]
            numeric_value = np.mean(values)  # Use mean for ranges
        else:
            value_parts = value.split()
            numeric_value = float(value_parts[0])

        unit = map_unit(value_parts[1]) if len(value_parts) > 1 else 'unknown'
        return numeric_value, unit
    except (IndexError, ValueError):
        return None, None

# Set the correct path to your images
image_dir = r"/content/sample_data/Images"
print(f"Looking for images in: {image_dir}")

# Limit the number of images to process
max_images = 1000
processed_images = 0

# Iterate over rows of the dataset
for i, row in data.iterrows():
    if processed_images >= max_images:
        break

    img_filename = f"{row['image_link'].split('/')[-1]}"
    img_path = os.path.join(image_dir, img_filename)

    if os.path.exists(img_path):
        try:
            # Preprocess and append the image data
            img_array = preprocess_image(img_path)
            x_train.append(img_array)

            # Parse numeric value and unit
            value_str = str(row['entity_value'])
            numeric_value, unit = parse_value_and_unit(value_str)

            if numeric_value is not None and unit != 'unknown':
                y_train_numeric.append(numeric_value)
                y_train_units.append(unit)
            else:
                print(f"Skipping row {i}: Unable to process '{value_str}'")
                continue

            processed_images += 1

            if processed_images % 100 == 0:
                print(f"Processed {processed_images} images")

        except Exception as e:
            print(f"Error processing image {img_path}: {str(e)}")
    else:
        print(f"Image not found: {img_path}")

# Convert lists to arrays for training
if x_train:
    X_train = np.vstack(x_train)
    y_train_numeric = np.array(y_train_numeric)

    # Encode units as integers and then convert to one-hot
    label_encoder = LabelEncoder()
    y_train_units_encoded = label_encoder.fit_transform(y_train_units)
    y_train_units_categorical = to_categorical(y_train_units_encoded)

    print(f"Training on {len(X_train)} images")

    # Check sizes before training
    if len(X_train) == len(y_train_numeric) == len(y_train_units_categorical):
        # Train the model with both numeric values and units
        model.fit(X_train, {'numeric_output': y_train_numeric, 'unit_output': y_train_units_categorical},
                  epochs=10, batch_size=32, validation_split=0.2)
    else:
        print("Data sizes do not match. Check your data processing pipeline.")

else:
    print("No images found or loaded. Please check the paths and files.")

# Save the model
model.save('entity_value_unit_model.h5')
print("Model saved as 'entity_value_unit_model.h5'")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Looking for images in: /content/sample_data/Images
# Skipping row 1: Unable to process '1.0 cup'
# Skipping row 21: Unable to process '4.0 gallon'
# Skipping row 25: Unable to process '48.0 volt'
# Skipping row 36: Unable to process '800.0 watt'
# Skipping row 37: Unable to process '36.0 volt'
# Skipping row 42: Unable to process '150.0 watt'
# Skipping row 43: Unable to process '150.0 watt'
# Skipping row 44: Unable to process '30.0 watt'
# Skipping row 45: Unable to process '30.0 watt'
# Skipping row 48: Unable to process '250.0 watt'
# Skipping row 62: Unable to process '60.0 watt'
# Skipping row 63: Unable to process '30.0 millilitre'
# Skipping row 64: Unable to process '30.0 millilitre'
# Skipping row 65: Unable to process '30.0 millilitre'
# Skipping row 66: Unable to process '30.0 millilitre'
# Skipping row 67: Unable to process '30.0 millilitre'
# Skipping row 81: Unable to process '3.0 cubic foot'
# Skipping row 92: Unable to process '0.55 watt'
# Skipping row 95: Unable to process '49.0 watt'
# Skipping row 100: Unable to process '500.0 millilitre'
# Skipping row 110: Unable to process '10.0 millilitre'
# Skipping row 111: Unable to process '200.0 millilitre'
# Processed 100 images
# Skipping row 138: Unable to process '60.0 watt'
# Skipping row 139: Unable to process '[100.0, 240.0] volt'
# Skipping row 140: Unable to process '25.0 millilitre'
# Skipping row 152: Unable to process '[8.0, 12.0] fluid ounce'
# Skipping row 154: Unable to process '12.0 volt'
# Skipping row 157: Unable to process '16.0 fluid ounce'
# Skipping row 161: Unable to process '12.0 volt'
# Skipping row 162: Unable to process '12.0 volt'
# Skipping row 163: Unable to process '12.0 volt'
# Skipping row 164: Unable to process '12.0 volt'
# Skipping row 169: Unable to process '[85.0, 265.0] volt'
# Skipping row 170: Unable to process '4.0 fluid ounce'
# Skipping row 171: Unable to process '4.0 fluid ounce'
# Skipping row 172: Unable to process '4.0 fluid ounce'
# Skipping row 173: Unable to process '0.7 millilitre'
# Skipping row 175: Unable to process '4.0 fluid ounce'
# Skipping row 178: Unable to process '8.0 watt'
# Skipping row 182: Unable to process '100.0 watt'
# Skipping row 183: Unable to process '100.0 watt'
# Skipping row 184: Unable to process '100.0 watt'
# Skipping row 185: Unable to process '100.0 watt'
# Skipping row 187: Unable to process '3.0 watt'
# Skipping row 189: Unable to process '3.0 millilitre'
# Skipping row 196: Unable to process '2.0 ton'
# Skipping row 204: Unable to process '1977.0 decilitre'
# Skipping row 206: Unable to process '100.0 millilitre'
# Skipping row 207: Unable to process '100.0 millilitre'
# Skipping row 208: Unable to process '100.0 millilitre'
# Skipping row 215: Unable to process '[25.0, 30.0] pound'
# Skipping row 219: Unable to process '2.55 cubic inch'
# Skipping row 227: Unable to process '7.0 volt'
# Skipping row 228: Unable to process '[175.0, 265.0] volt'
# Skipping row 248: Unable to process '6.0 ton'
# Skipping row 250: Unable to process '60.0 watt'
# Skipping row 251: Unable to process '21.6 watt'
# Skipping row 252: Unable to process '240.0 volt'
# Skipping row 254: Unable to process '120.0 volt'
# Processed 200 images
# Skipping row 292: Unable to process '20.0 watt'
# Skipping row 312: Unable to process '18.0 volt'
# Skipping row 315: Unable to process '240.0 volt'
# Skipping row 316: Unable to process '12.0 volt'
# Skipping row 317: Unable to process '12.0 volt'
# Skipping row 318: Unable to process '1.69 fluid ounce'
# Skipping row 319: Unable to process '64.0 fluid ounce'
# Skipping row 320: Unable to process '8.0 fluid ounce'
# Skipping row 321: Unable to process '8.0 fluid ounce'
# Skipping row 322: Unable to process '13.0 ton'
# Skipping row 323: Unable to process '[220.0, 240.0] volt'
# Skipping row 324: Unable to process '1000.0 watt'
# Skipping row 325: Unable to process '800.0 watt'
# Skipping row 342: Unable to process '36.0 volt'
# Skipping row 349: Unable to process '50.0 ton'
# Skipping row 353: Unable to process '24.0 watt'
# Skipping row 354: Unable to process '8.0 fluid ounce'
# Skipping row 356: Unable to process '2007.0 gallon'
# Skipping row 357: Unable to process '2006.0 gallon'
# Skipping row 358: Unable to process '2007.0 gallon'
# Processed 300 images
# Skipping row 381: Unable to process '72.0 watt'
# Skipping row 382: Unable to process '200.0 millilitre'
# Skipping row 388: Unable to process '54.0 watt'
# Skipping row 391: Unable to process '12.0 volt'
# Skipping row 392: Unable to process '12.0 volt'
# Skipping row 411: Unable to process '6.0 ton'
# Skipping row 414: Unable to process '66.0 watt'
# Skipping row 422: Unable to process '44115.0 ton'
# Skipping row 423: Unable to process '1.0 litre'
# Skipping row 424: Unable to process '36.0 volt'
# Skipping row 425: Unable to process '36.0 volt'
# Skipping row 426: Unable to process '250.0 watt'
# Skipping row 429: Unable to process '20.0 watt'
# Skipping row 446: Unable to process '24.0 volt'
# Skipping row 452: Unable to process '230.0 volt'
# Skipping row 453: Unable to process '30.0 watt'
# Skipping row 454: Unable to process '30.0 watt'
# Skipping row 459: Unable to process '2325.0 microgram'
# Skipping row 460: Unable to process '250.0 watt'
# Skipping row 464: Unable to process '5.0 volt'
# Skipping row 465: Unable to process '5.0 volt'
# Skipping row 468: Unable to process '200.0 millilitre'
# Skipping row 474: Unable to process '210.0 watt'
# Skipping row 475: Unable to process '15.0 watt'
# Skipping row 499: Unable to process '[11.0, 12.0] ounce'
# Processed 400 images
# Skipping row 507: Unable to process '[70.0, 100.0] millilitre'
# Skipping row 508: Unable to process '36.0 volt'
# Skipping row 520: Unable to process '25.0 volt'
# Skipping row 521: Unable to process '20.0 watt'
# Skipping row 533: Unable to process '5 millilitre'
# Skipping row 534: Unable to process '5 millilitre'
# Skipping row 544: Unable to process '699.0 litre'
# Skipping row 552: Unable to process '10.0 watt'
# Skipping row 555: Unable to process '9361.0 ton'
# Skipping row 568: Unable to process '1800.0 watt'
# Skipping row 579: Unable to process '100.0 millilitre'
# Skipping row 581: Unable to process '30.0 millilitre'
# Skipping row 584: Unable to process '2.0 ton'
# Skipping row 594: Unable to process '8.0 watt'
# Skipping row 595: Unable to process '90.0 microgram'
# Skipping row 596: Unable to process '90.0 microgram'
# Skipping row 597: Unable to process '90.0 microgram'
# Processed 500 images
# Skipping row 630: Unable to process '128.0 fluid ounce'
# Skipping row 631: Unable to process '128.0 fluid ounce'
# Skipping row 632: Unable to process '10.0 millilitre'
# Skipping row 633: Unable to process '10.0 millilitre'
# Skipping row 634: Unable to process '10.0 millilitre'
# Skipping row 635: Unable to process '10.0 millilitre'
# Skipping row 640: Unable to process '500.0 watt'
# Skipping row 641: Unable to process '48.0 volt'
# Skipping row 642: Unable to process '12.0 volt'
# Skipping row 662: Unable to process '1500.0 watt'
# Skipping row 672: Unable to process '[17.0, 21.0] kilogram'
# Skipping row 673: Unable to process '[13.0, 16.0] kilogram'
# Skipping row 674: Unable to process '[13.0, 16.0] kilogram'
# Skipping row 676: Unable to process '250.0 millilitre'
# Skipping row 677: Unable to process '250.0 millilitre'
# Skipping row 678: Unable to process '250.0 millilitre'
# Skipping row 679: Unable to process '250.0 millilitre'
# Skipping row 680: Unable to process '250.0 millilitre'
# Skipping row 681: Unable to process '250.0 millilitre'
# Skipping row 682: Unable to process '250.0 millilitre'
# Skipping row 691: Unable to process '60.0 watt'
# Skipping row 693: Unable to process '4.0 quart'
# Skipping row 694: Unable to process '4.0 quart'
# Skipping row 695: Unable to process '4.0 quart'
# Skipping row 704: Unable to process '2.4 watt'
# Skipping row 707: Unable to process '4.0 ton'
# Skipping row 708: Unable to process '110.0 volt'
# Skipping row 709: Unable to process '60.0 watt'
# Skipping row 712: Unable to process '250.0 volt'
# Skipping row 721: Unable to process '230.0 volt'
# Skipping row 722: Unable to process '[11.0, 17.0] volt'
# Skipping row 723: Unable to process '18.0 volt'
# Skipping row 737: Unable to process '250.0 watt'
# Skipping row 745: Unable to process '200 millilitre'
# Skipping row 753: Unable to process '65.0 ton'
# Processed 600 images
# Skipping row 758: Unable to process '21116.0 ton'
# Skipping row 760: Unable to process '85.0 ton'
# Skipping row 761: Unable to process '50.0 watt'
# Skipping row 762: Unable to process '50.0 watt'
# Skipping row 763: Unable to process '50.0 watt'
# Skipping row 764: Unable to process '50.0 watt'
# Skipping row 765: Unable to process '50.0 watt'
# Skipping row 766: Unable to process '50.0 watt'
# Skipping row 767: Unable to process '120.0 volt'
# Skipping row 771: Unable to process '[220.0, 250.0] volt'
# Skipping row 778: Unable to process '600.0 watt'
# Skipping row 786: Unable to process '42.0 watt'
# Skipping row 793: Unable to process '18.0 watt'
# Skipping row 797: Unable to process '[1.0, 2.0] gram'
# Skipping row 798: Unable to process '3.0 horsepower'
# Skipping row 799: Unable to process '[7.0, 25.0] kilogram'
# Skipping row 802: Unable to process '100.0 millilitre'
# Skipping row 805: Unable to process '2.0 volt'
# Skipping row 806: Unable to process '12.0 volt'
# Skipping row 807: Unable to process '12.0 volt'
# Skipping row 808: Unable to process '1.76 fluid ounce'
# Skipping row 809: Unable to process '1.76 fluid ounce'
# Skipping row 810: Unable to process '1.76 fluid ounce'
# Skipping row 811: Unable to process '50.0 fluid ounce'
# Skipping row 812: Unable to process '1.76 fluid ounce'
# Skipping row 814: Unable to process '0.75 watt'
# Skipping row 815: Unable to process '0.75 watt'
# Skipping row 816: Unable to process '60.0 watt'
# Skipping row 822: Unable to process '750.0 watt'
# Skipping row 824: Unable to process '22.5 watt'
# Skipping row 836: Unable to process '1.69 fluid ounce'
# Skipping row 837: Unable to process '1.69 fluid ounce'
# Skipping row 838: Unable to process '1.69 fluid ounce'
# Skipping row 839: Unable to process '1.69 fluid ounce'
# Skipping row 851: Unable to process '8.0 fluid ounce'
# Skipping row 852: Unable to process '1080.0 horsepower'
# Skipping row 880: Unable to process '4.0 watt'
# Skipping row 891: Unable to process '1000.0 microgram'
# Skipping row 892: Unable to process '1000.0 microgram'
# Skipping row 893: Unable to process '1000.0 microgram'
# Skipping row 894: Unable to process '1000.0 microgram'
# Skipping row 895: Unable to process '1000.0 microgram'
# Processed 700 images
# Skipping row 899: Unable to process '[135.0, 150.0] kilogram'
# Skipping row 900: Unable to process '22.0 kilowatt'
# Skipping row 904: Unable to process '[5.0, 11.0] kilogram'
# Skipping row 905: Unable to process '[5.0, 11.0] kilogram'
# Skipping row 908: Unable to process '100.0 litre'
# Skipping row 909: Unable to process '1913.0 decilitre'
# Skipping row 910: Unable to process '100.0 millilitre'
# Skipping row 929: Unable to process '7.2 volt'
# Skipping row 939: Unable to process '75.0 microgram'
# Skipping row 940: Unable to process '75.0 microgram'
# Skipping row 944: Unable to process '30.0 watt'
# Skipping row 945: Unable to process '100.0 watt'
# Skipping row 946: Unable to process '100.0 watt'
# Skipping row 948: Unable to process '48.0 volt'
# Skipping row 949: Unable to process '5.0 volt'
# Skipping row 955: Unable to process '6.0 watt'
# Skipping row 956: Unable to process '30.0 volt'
# Skipping row 980: Unable to process '1080.0 horsepower'
# Skipping row 989: Unable to process '750.0 watt'
# Skipping row 990: Unable to process '750.0 watt'
# Skipping row 991: Unable to process '220.0 volt'
# Skipping row 998: Unable to process '0.5 volt'
# Skipping row 1004: Unable to process '1.5 watt'
# Skipping row 1005: Unable to process '29.0 litre'
# Skipping row 1008: Unable to process '[110.0, 120.0] volt'
# Skipping row 1010: Unable to process '5.0 watt'
# Skipping row 1016: Unable to process '18.0 watt'
# Skipping row 1017: Unable to process '[220.0, 240.0] volt'
# Skipping row 1018: Unable to process '18.0 watt'
# Skipping row 1020: Unable to process '[1.0, 2.0] ounce'
# Skipping row 1022: Unable to process '1.0 watt'
# Skipping row 1024: Unable to process '[0.0, 5.0] kilogram'
# Skipping row 1025: Unable to process '60.0 watt'
# Skipping row 1026: Unable to process '[110.0, 240.0] volt'
# Skipping row 1027: Unable to process '32.0 fluid ounce'
# Skipping row 1029: Unable to process '[2003.0, 2015.0] gram'
# Processed 800 images
# Skipping row 1042: Unable to process '200.0 millilitre'
# Skipping row 1043: Unable to process '200.0 millilitre'
# Skipping row 1044: Unable to process '200.0 millilitre'
# Skipping row 1055: Unable to process '12.0 volt'
# Skipping row 1056: Unable to process '8.0 fluid ounce'
# Skipping row 1057: Unable to process '8.0 fluid ounce'
# Skipping row 1058: Unable to process '60.0 watt'
# Skipping row 1059: Unable to process '100.0 watt'
# Skipping row 1078: Unable to process '25.0 litre'
# Skipping row 1085: Unable to process '0.4 litre'
# Error processing image /content/sample_data/Images/41NH8WgeBOL.jpg: image file is truncated (2 bytes not processed)
# Skipping row 1101: Unable to process '70.0 watt'
# Skipping row 1105: Unable to process '100.0 millilitre'
# Skipping row 1115: Unable to process '240.0 watt'
# Skipping row 1116: Unable to process '240.0 watt'
# Skipping row 1117: Unable to process '240.0 watt'
# Skipping row 1118: Unable to process '240.0 watt'
# Skipping row 1119: Unable to process '240.0 watt'
# Skipping row 1122: Unable to process '1.0 ton'
# Processed 900 images
# Skipping row 1161: Unable to process '48.0 volt'
# Skipping row 1163: Unable to process '16.0 fluid ounce'
# Skipping row 1164: Unable to process '16.0 fluid ounce'
# Skipping row 1165: Unable to process '16.0 fluid ounce'
# Skipping row 1166: Unable to process '16.0 fluid ounce'
# Skipping row 1186: Unable to process '65.0 watt'
# Skipping row 1187: Unable to process '50.0 watt'
# Skipping row 1188: Unable to process '220.0 volt'
# Skipping row 1189: Unable to process '100.0 watt'
# Skipping row 1190: Unable to process '110.0 volt'
# Skipping row 1191: Unable to process '110.0 volt'
# Skipping row 1193: Unable to process '1.5 volt'
# Skipping row 1194: Unable to process '110.0 volt'
# Skipping row 1195: Unable to process '12.0 watt'
# Skipping row 1211: Unable to process '1.0 ton'
# Skipping row 1212: Unable to process '[5.5, 10.0] kilogram'
# Skipping row 1213: Unable to process '2.0 litre'
# Skipping row 1214: Unable to process '550.0 watt'
# Skipping row 1215: Unable to process '550.0 watt'
# Skipping row 1217: Unable to process '250.0 millilitre'
# Skipping row 1222: Unable to process '[8.0, 12.0] fluid ounce'
# Skipping row 1228: Unable to process '12.0 volt'
# Skipping row 1231: Unable to process '50.0 volt'
# Skipping row 1238: Unable to process '[85.0, 265.0] volt'
# Skipping row 1239: Unable to process '15.0 watt'
# Skipping row 1243: Unable to process '100.0 millilitre'
# Skipping row 1248: Unable to process '3.0 watt'
# Skipping row 1278: Unable to process '3.0 ton'
# Skipping row 1279: Unable to process '100.0 microgram'
# Processed 1000 images
# Training on 1281 images
# Data sizes do not match. Check your data processing pipeline.
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved as 'entity_value_unit_model.h5'

# %%
# %pip install constants
import re
import constants
import os
import requests
import pandas as pd
import multiprocessing
import time
from time import time as timer
from tqdm import tqdm
import numpy as np
from pathlib import Path
from functools import partial
import requests
import urllib
from PIL import Image

def common_mistake(unit):
    if unit in constants.allowed_units:
        return unit
    if unit.replace('ter', 'tre') in constants.allowed_units:
        return unit.replace('ter', 'tre')
    if unit.replace('feet', 'foot') in constants.allowed_units:
        return unit.replace('feet', 'foot')
    return unit

def parse_string(s):
    s_stripped = "" if s==None or str(s)=='nan' else s.strip()
    if s_stripped == "":
        return None, None
    pattern = re.compile(r'^-?\d+(\.\d+)?\s+[a-zA-Z\s]+$')
    if not pattern.match(s_stripped):
        raise ValueError("Invalid format in {}".format(s))
    parts = s_stripped.split(maxsplit=1)
    number = float(parts[0])
    unit = common_mistake(parts[1])
    if unit not in constants.allowed_units:
        raise ValueError("Invalid unit [{}] found in {}. Allowed units: {}".format(
            unit, s, constants.allowed_units))
    return number, unit


def create_placeholder_image(image_save_path):
    try:
        placeholder_image = Image.new('RGB', (100, 100), color='black')
        placeholder_image.save(image_save_path)
    except Exception as e:
        return

def download_image(image_link, save_folder, retries=3, delay=3):
    if not isinstance(image_link, str):
        return

    filename = Path(image_link).name
    image_save_path = os.path.join(save_folder, filename)

    if os.path.exists(image_save_path):
        return

    for _ in range(retries):
        try:
            urllib.request.urlretrieve(image_link, image_save_path)
            return
        except:
            time.sleep(delay)

    create_placeholder_image(image_save_path) #Create a black placeholder image for invalid links/images

def download_images(image_links, download_folder, allow_multiprocessing=True):
    if not os.path.exists(download_folder):
        os.makedirs(download_folder)

    if allow_multiprocessing:
        download_image_partial = partial(
            download_image, save_folder=download_folder, retries=3, delay=3)

        with multiprocessing.Pool(64) as pool:
            list(tqdm(pool.imap(download_image_partial, image_links), total=len(image_links)))
            pool.close()
            pool.join()
    else:
        for image_link in tqdm(image_links, total=len(image_links)):
            download_image(image_link, save_folder=download_folder, retries=3, delay=3)

download_images(test['image_link'], '/content/sample_data/Test_Images')
#Image path : /content/sample_data/Images
# Out:
# Requirement already satisfied: constants in /usr/local/lib/python3.10/dist-packages (0.6.0)
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 100%|██████████| 131187/131187 [18:01<00:00, 121.26it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %%
import numpy as np
import pandas as pd
import os
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder

# Load the saved model
model = tf.keras.models.load_model('entity_value_unit_model.h5')

# Load your test data
test_data = pd.read_csv('/content/test.csv')

# Set the correct path to your images
test_image_dir = r"/content/sample_data/Test_Images"
print(f"Looking for test images in: {test_image_dir}")

# Ensure the prediction directory exists
prediction_dir = '/content/sample_data/Prediction'
if not os.path.exists(prediction_dir):
    os.makedirs(prediction_dir)

# Function to preprocess the image
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img_array

# Load the label encoder used during training to map unit predictions back to unit names
label_encoder = LabelEncoder()
unit_labels = list(unit_mapping.values())  # List of all possible unit labels
label_encoder.fit(unit_labels)

# Lists to store predictions
predictions = []

# Iterate over the test dataset
for i, row in test_data.iterrows():
    img_filename = f"{row['image_link'].split('/')[-1]}"
    img_path = os.path.join(test_image_dir, img_filename)

    if os.path.exists(img_path):
        try:
            print(f"Processing image {i+1}/{len(test_data)}: {img_path}")
            # Preprocess the test image
            img_array = preprocess_image(img_path)

            # Predict both numeric value and unit
            numeric_pred, unit_pred = model.predict(img_array)

            # Get the predicted numeric value
            predicted_value = numeric_pred[0][0]

            # Get the predicted unit (from softmax probabilities)
            predicted_unit_index = np.argmax(unit_pred, axis=1)[0]
            predicted_unit = label_encoder.inverse_transform([predicted_unit_index])[0]

            # If both value and unit are valid, format the prediction
            if predicted_value is not None and predicted_unit is not None:
                prediction = f"{predicted_value:.2f} {predicted_unit}s" if predicted_value > 1 else f"{predicted_value:.2f} {predicted_unit}"
            else:
                # If either value or unit prediction fails, append an empty string
                prediction = ""

            predictions.append(prediction)

        except Exception as e:
            print(f"Error processing image {img_path}: {str(e)}")
            predictions.append("")  # Append an empty string if prediction fails
    else:
        print(f"Image not found: {img_path}")
        predictions.append("")  # Append an empty string if image is not found

# Add the predictions to the test dataset and only keep the 'index' and 'entity_value' columns
test_data['entity_value'] = predictions
output_data = test_data[['index', 'entity_value']]

# Save the results to a new CSV file with only 'index' and 'entity_value' columns
output_path = os.path.join(prediction_dir, '/content/sample_data/Prediction/test_predictions.csv')
output_data.to_csv(output_path, index=False)

print(f"Predictions saved to {output_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Error processing image /content/sample_data/Test_Images/518LBxrFS8L.jpg: y contains previously unseen labels: [27]
# Processing image 28325/131187: /content/sample_data/Test_Images/518LOZXorML.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 28326/131187: /content/sample_data/Test_Images/518LOZXorML.jpg
# 1/1 [==============================] - 0s 37ms/step
# Processing image 28327/131187: /content/sample_data/Test_Images/518LYuosi3L.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 28328/131187: /content/sample_data/Test_Images/518Lbr56u9L.jpg
# 1/1 [==============================] - 0s 35ms/step
# Processing image 28329/131187: /content/sample_data/Test_Images/518Lbr56u9L.jpg
# 1/1 [==============================] - 0s 35ms/step
# Processing image 28330/131187: /content/sample_data/Test_Images/518LggywMGL.jpg
# 1/1 [==============================] - 0s 31ms/step
# Processing image 28331/131187: /content/sample_data/Test_Images/518LglB17ZL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28332/131187: /content/sample_data/Test_Images/518LipDbc7L.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28333/131187: /content/sample_data/Test_Images/518LofR6h2L.jpg
# 1/1 [==============================] - 0s 34ms/step
# Processing image 28334/131187: /content/sample_data/Test_Images/518LxlLt1fL.jpg
# 1/1 [==============================] - 0s 37ms/step
# Processing image 28335/131187: /content/sample_data/Test_Images/518LxlLt1fL.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 28336/131187: /content/sample_data/Test_Images/518LxlLt1fL.jpg
# 1/1 [==============================] - 0s 38ms/step
# Processing image 28337/131187: /content/sample_data/Test_Images/518M0EON9zS.jpg
# 1/1 [==============================] - 0s 55ms/step
# Processing image 28338/131187: /content/sample_data/Test_Images/518M0EON9zS.jpg
# 1/1 [==============================] - 0s 64ms/step
# Processing image 28339/131187: /content/sample_data/Test_Images/518M7kKUWGL.jpg
# 1/1 [==============================] - 0s 68ms/step
# Processing image 28340/131187: /content/sample_data/Test_Images/518M7kKUWGL.jpg
# 1/1 [==============================] - 0s 90ms/step
# Processing image 28341/131187: /content/sample_data/Test_Images/518MYKF+0XL.jpg
# 1/1 [==============================] - 0s 59ms/step
# Processing image 28342/131187: /content/sample_data/Test_Images/518MfTQRNdL.jpg
# 1/1 [==============================] - 0s 63ms/step
# Processing image 28343/131187: /content/sample_data/Test_Images/518MfTQRNdL.jpg
# 1/1 [==============================] - 0s 49ms/step
# Processing image 28344/131187: /content/sample_data/Test_Images/518MfTQRNdL.jpg
# 1/1 [==============================] - 0s 51ms/step
# Processing image 28345/131187: /content/sample_data/Test_Images/518MmgHa2BL.jpg
# 1/1 [==============================] - 0s 47ms/step
# Processing image 28346/131187: /content/sample_data/Test_Images/518MvQTKqdL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Processing image 28347/131187: /content/sample_data/Test_Images/518N0Jxp-2L.jpg
# 1/1 [==============================] - 0s 48ms/step
# Error processing image /content/sample_data/Test_Images/518N0Jxp-2L.jpg: y contains previously unseen labels: [25]
# Processing image 28348/131187: /content/sample_data/Test_Images/518N30nzdqS.jpg
# 1/1 [==============================] - 0s 83ms/step
# Processing image 28349/131187: /content/sample_data/Test_Images/518N7TWtCHL.jpg
# 1/1 [==============================] - 0s 71ms/step
# Processing image 28350/131187: /content/sample_data/Test_Images/518N7TWtCHL.jpg
# 1/1 [==============================] - 0s 61ms/step
# Processing image 28351/131187: /content/sample_data/Test_Images/518NFOSq97L.jpg
# 1/1 [==============================] - 0s 45ms/step
# Processing image 28352/131187: /content/sample_data/Test_Images/518NIL-TV2L.jpg
# 1/1 [==============================] - 0s 67ms/step
# Processing image 28353/131187: /content/sample_data/Test_Images/518NIL-TV2L.jpg
# 1/1 [==============================] - 0s 57ms/step
# Processing image 28354/131187: /content/sample_data/Test_Images/518NJt4fE8L.jpg
# 1/1 [==============================] - 0s 54ms/step
# Processing image 28355/131187: /content/sample_data/Test_Images/518NJt4fE8L.jpg
# 1/1 [==============================] - 0s 60ms/step
# Processing image 28356/131187: /content/sample_data/Test_Images/518NKnIaLXL.jpg
# 1/1 [==============================] - 0s 57ms/step
# Processing image 28357/131187: /content/sample_data/Test_Images/518NL6tZmfL.jpg
# 1/1 [==============================] - 0s 53ms/step
# Processing image 28358/131187: /content/sample_data/Test_Images/518NV2bSPNL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28359/131187: /content/sample_data/Test_Images/518NWzT5+jS.jpg
# 1/1 [==============================] - 0s 69ms/step
# Processing image 28360/131187: /content/sample_data/Test_Images/518NaZkx1qL.jpg
# 1/1 [==============================] - 0s 72ms/step
# Error processing image /content/sample_data/Test_Images/518NaZkx1qL.jpg: y contains previously unseen labels: [39]
# Processing image 28361/131187: /content/sample_data/Test_Images/518Nmp13hLL.jpg
# 1/1 [==============================] - 0s 61ms/step
# Error processing image /content/sample_data/Test_Images/518Nmp13hLL.jpg: y contains previously unseen labels: [27]
# Processing image 28362/131187: /content/sample_data/Test_Images/518NoUZ08qL.jpg
# 1/1 [==============================] - 0s 41ms/step
# Processing image 28363/131187: /content/sample_data/Test_Images/518NtS4Z6RL.jpg
# 1/1 [==============================] - 0s 67ms/step
# Processing image 28364/131187: /content/sample_data/Test_Images/518NuK8plcL.jpg
# 1/1 [==============================] - 0s 54ms/step
# Error processing image /content/sample_data/Test_Images/518NuK8plcL.jpg: y contains previously unseen labels: [27]
# Processing image 28365/131187: /content/sample_data/Test_Images/518NuK8plcL.jpg
# 1/1 [==============================] - 0s 54ms/step
# Error processing image /content/sample_data/Test_Images/518NuK8plcL.jpg: y contains previously unseen labels: [27]
# Processing image 28366/131187: /content/sample_data/Test_Images/518NyhpiQaL.jpg
# 1/1 [==============================] - 0s 57ms/step
# Error processing image /content/sample_data/Test_Images/518NyhpiQaL.jpg: y contains previously unseen labels: [49]
# Processing image 28367/131187: /content/sample_data/Test_Images/518NyhpiQaL.jpg
# 1/1 [==============================] - 0s 63ms/step
# Error processing image /content/sample_data/Test_Images/518NyhpiQaL.jpg: y contains previously unseen labels: [49]
# Processing image 28368/131187: /content/sample_data/Test_Images/518Nz8fZmbL.jpg
# 1/1 [==============================] - 0s 57ms/step
# Processing image 28369/131187: /content/sample_data/Test_Images/518O7kaZ4UL.jpg
# 1/1 [==============================] - 0s 63ms/step
# Processing image 28370/131187: /content/sample_data/Test_Images/518O7kaZ4UL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28371/131187: /content/sample_data/Test_Images/518OcXqU5nL.jpg
# 1/1 [==============================] - 0s 87ms/step
# Error processing image /content/sample_data/Test_Images/518OcXqU5nL.jpg: y contains previously unseen labels: [27]
# Processing image 28372/131187: /content/sample_data/Test_Images/518Onx-iniL.jpg
# 1/1 [==============================] - 0s 38ms/step
# Processing image 28373/131187: /content/sample_data/Test_Images/518OreoRJTL.jpg
# 1/1 [==============================] - 0s 47ms/step
# Processing image 28374/131187: /content/sample_data/Test_Images/518OyawMS3L.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28375/131187: /content/sample_data/Test_Images/518PJjyjNeL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28376/131187: /content/sample_data/Test_Images/518PLU1Q6bL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28377/131187: /content/sample_data/Test_Images/518PQ9h5K1L.jpg
# 1/1 [==============================] - 0s 45ms/step
# Error processing image /content/sample_data/Test_Images/518PQ9h5K1L.jpg: y contains previously unseen labels: [40]
# Processing image 28378/131187: /content/sample_data/Test_Images/518PQ9h5K1L.jpg
# 1/1 [==============================] - 0s 59ms/step
# Error processing image /content/sample_data/Test_Images/518PQ9h5K1L.jpg: y contains previously unseen labels: [40]
# Processing image 28379/131187: /content/sample_data/Test_Images/518PX1JO1EL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28380/131187: /content/sample_data/Test_Images/518PwS4XCFL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Processing image 28381/131187: /content/sample_data/Test_Images/518Q0lDEYvL.jpg
# 1/1 [==============================] - 0s 53ms/step
# Processing image 28382/131187: /content/sample_data/Test_Images/518Q1qFmc9S.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28383/131187: /content/sample_data/Test_Images/518Q1qFmc9S.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28384/131187: /content/sample_data/Test_Images/518Q4k9RfXL.jpg
# 1/1 [==============================] - 0s 45ms/step
# Error processing image /content/sample_data/Test_Images/518Q4k9RfXL.jpg: y contains previously unseen labels: [27]
# Processing image 28385/131187: /content/sample_data/Test_Images/518Q4k9RfXL.jpg
# 1/1 [==============================] - 0s 60ms/step
# Error processing image /content/sample_data/Test_Images/518Q4k9RfXL.jpg: y contains previously unseen labels: [27]
# Processing image 28386/131187: /content/sample_data/Test_Images/518Q4k9RfXL.jpg
# 1/1 [==============================] - 0s 41ms/step
# Error processing image /content/sample_data/Test_Images/518Q4k9RfXL.jpg: y contains previously unseen labels: [27]
# Processing image 28387/131187: /content/sample_data/Test_Images/518QAaedh+L.jpg
# 1/1 [==============================] - 0s 42ms/step
# Error processing image /content/sample_data/Test_Images/518QAaedh+L.jpg: y contains previously unseen labels: [40]
# Processing image 28388/131187: /content/sample_data/Test_Images/518QAaedh+L.jpg
# 1/1 [==============================] - 0s 65ms/step
# Error processing image /content/sample_data/Test_Images/518QAaedh+L.jpg: y contains previously unseen labels: [40]
# Processing image 28389/131187: /content/sample_data/Test_Images/518QAaedh+L.jpg
# 1/1 [==============================] - 0s 40ms/step
# Error processing image /content/sample_data/Test_Images/518QAaedh+L.jpg: y contains previously unseen labels: [40]
# Processing image 28390/131187: /content/sample_data/Test_Images/518QDId2NFL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28391/131187: /content/sample_data/Test_Images/518QDId2NFL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28392/131187: /content/sample_data/Test_Images/518QRhYe5+L.jpg
# 1/1 [==============================] - 0s 50ms/step
# Processing image 28393/131187: /content/sample_data/Test_Images/518Qg6avn+L.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 28394/131187: /content/sample_data/Test_Images/518Qveujj5L.jpg
# 1/1 [==============================] - 0s 39ms/step
# Error processing image /content/sample_data/Test_Images/518Qveujj5L.jpg: y contains previously unseen labels: [43]
# Processing image 28395/131187: /content/sample_data/Test_Images/518RCRD1-3L.jpg
# 1/1 [==============================] - 0s 43ms/step
# Processing image 28396/131187: /content/sample_data/Test_Images/518RCRD1-3L.jpg
# 1/1 [==============================] - 0s 43ms/step
# Processing image 28397/131187: /content/sample_data/Test_Images/518RCRD1-3L.jpg
# 1/1 [==============================] - 0s 35ms/step
# Processing image 28398/131187: /content/sample_data/Test_Images/518REv0cwPL.jpg
# 1/1 [==============================] - 0s 38ms/step
# Processing image 28399/131187: /content/sample_data/Test_Images/518RFZIU6FL.jpg
# 1/1 [==============================] - 0s 37ms/step
# Error processing image /content/sample_data/Test_Images/518RFZIU6FL.jpg: y contains previously unseen labels: [40]
# Processing image 28400/131187: /content/sample_data/Test_Images/518RFZIU6FL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Error processing image /content/sample_data/Test_Images/518RFZIU6FL.jpg: y contains previously unseen labels: [40]
# Processing image 28401/131187: /content/sample_data/Test_Images/518RFZIU6FL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Error processing image /content/sample_data/Test_Images/518RFZIU6FL.jpg: y contains previously unseen labels: [40]
# Processing image 28402/131187: /content/sample_data/Test_Images/518RK3Wls2L.jpg
# 1/1 [==============================] - 0s 55ms/step
# Processing image 28403/131187: /content/sample_data/Test_Images/518RR1FIFlL.jpg
# 1/1 [==============================] - 0s 49ms/step
# Processing image 28404/131187: /content/sample_data/Test_Images/518RV+yNq-L.jpg
# 1/1 [==============================] - 0s 36ms/step
# Error processing image /content/sample_data/Test_Images/518RV+yNq-L.jpg: y contains previously unseen labels: [27]
# Processing image 28405/131187: /content/sample_data/Test_Images/518RV+yNq-L.jpg
# 1/1 [==============================] - 0s 31ms/step
# Error processing image /content/sample_data/Test_Images/518RV+yNq-L.jpg: y contains previously unseen labels: [27]
# Processing image 28406/131187: /content/sample_data/Test_Images/518ReF7UWxL.jpg
# 1/1 [==============================] - 0s 41ms/step
# Error processing image /content/sample_data/Test_Images/518ReF7UWxL.jpg: y contains previously unseen labels: [29]
# Processing image 28407/131187: /content/sample_data/Test_Images/518Rl2-UFVL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Processing image 28408/131187: /content/sample_data/Test_Images/518Rupe1x+S.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28409/131187: /content/sample_data/Test_Images/518SNoFrSgL.jpg
# 1/1 [==============================] - 0s 45ms/step
# Processing image 28410/131187: /content/sample_data/Test_Images/518SNoFrSgL.jpg
# 1/1 [==============================] - 0s 38ms/step
# Processing image 28411/131187: /content/sample_data/Test_Images/518ScrrjHTL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Error processing image /content/sample_data/Test_Images/518ScrrjHTL.jpg: y contains previously unseen labels: [26]
# Processing image 28412/131187: /content/sample_data/Test_Images/518SenBqXdL.jpg
# 1/1 [==============================] - 0s 30ms/step
# Processing image 28413/131187: /content/sample_data/Test_Images/518SenBqXdL.jpg
# 1/1 [==============================] - 0s 32ms/step
# Processing image 28414/131187: /content/sample_data/Test_Images/518SoUezTOL.jpg
# 1/1 [==============================] - 0s 38ms/step
# Processing image 28415/131187: /content/sample_data/Test_Images/518SqNPPN0S.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 28416/131187: /content/sample_data/Test_Images/518SqNPPN0S.jpg
# 1/1 [==============================] - 0s 59ms/step
# Processing image 28417/131187: /content/sample_data/Test_Images/518Squb0n6L.jpg
# 1/1 [==============================] - 0s 41ms/step
# Error processing image /content/sample_data/Test_Images/518Squb0n6L.jpg: y contains previously unseen labels: [39]
# Processing image 28418/131187: /content/sample_data/Test_Images/518Squb0n6L.jpg
# 1/1 [==============================] - 0s 40ms/step
# Error processing image /content/sample_data/Test_Images/518Squb0n6L.jpg: y contains previously unseen labels: [39]
# Processing image 28419/131187: /content/sample_data/Test_Images/518SsoatpRL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28420/131187: /content/sample_data/Test_Images/518Suz0m--L.jpg
# 1/1 [==============================] - 0s 47ms/step
# Error processing image /content/sample_data/Test_Images/518Suz0m--L.jpg: y contains previously unseen labels: [29]
# Processing image 28421/131187: /content/sample_data/Test_Images/518SvVr882L.jpg
# 1/1 [==============================] - 0s 28ms/step
# Error processing image /content/sample_data/Test_Images/518SvVr882L.jpg: y contains previously unseen labels: [39]
# Processing image 28422/131187: /content/sample_data/Test_Images/518T-w8J7NL.jpg
# 1/1 [==============================] - 0s 31ms/step
# Processing image 28423/131187: /content/sample_data/Test_Images/518T-w8J7NL.jpg
# 1/1 [==============================] - 0s 38ms/step
# Processing image 28424/131187: /content/sample_data/Test_Images/518T2FK2dxL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28425/131187: /content/sample_data/Test_Images/518T2FK2dxL.jpg
# 1/1 [==============================] - 0s 43ms/step
# Processing image 28426/131187: /content/sample_data/Test_Images/518T5f3jOIS.jpg
# 1/1 [==============================] - 0s 45ms/step
# Error processing image /content/sample_data/Test_Images/518T5f3jOIS.jpg: y contains previously unseen labels: [27]
# Processing image 28427/131187: /content/sample_data/Test_Images/518T5f3jOIS.jpg
# 1/1 [==============================] - 0s 56ms/step
# Error processing image /content/sample_data/Test_Images/518T5f3jOIS.jpg: y contains previously unseen labels: [27]
# Processing image 28428/131187: /content/sample_data/Test_Images/518T91P6M+L.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28429/131187: /content/sample_data/Test_Images/518T91P6M+L.jpg
# 1/1 [==============================] - 0s 41ms/step
# Processing image 28430/131187: /content/sample_data/Test_Images/518TBozM5ML.jpg
# 1/1 [==============================] - 0s 32ms/step
# Processing image 28431/131187: /content/sample_data/Test_Images/518TBozM5ML.jpg
# 1/1 [==============================] - 0s 37ms/step
# Processing image 28432/131187: /content/sample_data/Test_Images/518TIARDIOS.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 28433/131187: /content/sample_data/Test_Images/518TIARDIOS.jpg
# 1/1 [==============================] - 0s 49ms/step
# Processing image 28434/131187: /content/sample_data/Test_Images/518TIk08RdS.jpg
# 1/1 [==============================] - 0s 33ms/step
# Processing image 28435/131187: /content/sample_data/Test_Images/518TMkuJ-dL.jpg
# 1/1 [==============================] - 0s 33ms/step
# Error processing image /content/sample_data/Test_Images/518TMkuJ-dL.jpg: y contains previously unseen labels: [28]
# Processing image 28436/131187: /content/sample_data/Test_Images/518TW+hyV2L.jpg
# 1/1 [==============================] - 0s 35ms/step
# Error processing image /content/sample_data/Test_Images/518TW+hyV2L.jpg: y contains previously unseen labels: [27]
# Processing image 28437/131187: /content/sample_data/Test_Images/518TW+hyV2L.jpg
# 1/1 [==============================] - 0s 34ms/step
# Error processing image /content/sample_data/Test_Images/518TW+hyV2L.jpg: y contains previously unseen labels: [27]
# Processing image 28438/131187: /content/sample_data/Test_Images/518TWGrIJzL.jpg
# 1/1 [==============================] - 0s 50ms/step
# Processing image 28439/131187: /content/sample_data/Test_Images/518TYWp2bGL.jpg
# 1/1 [==============================] - 0s 52ms/step
# Error processing image /content/sample_data/Test_Images/518TYWp2bGL.jpg: y contains previously unseen labels: [27]
# Processing image 28440/131187: /content/sample_data/Test_Images/518Tk7tUzhL.jpg
# 1/1 [==============================] - 0s 55ms/step
# Processing image 28441/131187: /content/sample_data/Test_Images/518Tu4y-RpL.jpg
# 1/1 [==============================] - 0s 49ms/step
# Processing image 28442/131187: /content/sample_data/Test_Images/518TvYQOt1L.jpg
# 1/1 [==============================] - 0s 52ms/step
# Processing image 28443/131187: /content/sample_data/Test_Images/518TvYQOt1L.jpg
# 1/1 [==============================] - 0s 69ms/step
# Processing image 28444/131187: /content/sample_data/Test_Images/518U08DS9DL.jpg
# 1/1 [==============================] - 0s 49ms/step
# Error processing image /content/sample_data/Test_Images/518U08DS9DL.jpg: y contains previously unseen labels: [27]
# Processing image 28445/131187: /content/sample_data/Test_Images/518U08DS9DL.jpg
# 1/1 [==============================] - 0s 80ms/step
# Error processing image /content/sample_data/Test_Images/518U08DS9DL.jpg: y contains previously unseen labels: [27]
# Processing image 28446/131187: /content/sample_data/Test_Images/518U93wky4L.jpg
# 1/1 [==============================] - 0s 55ms/step
# Error processing image /content/sample_data/Test_Images/518U93wky4L.jpg: y contains previously unseen labels: [40]
# Processing image 28447/131187: /content/sample_data/Test_Images/518UEVT7nIL.jpg
# 1/1 [==============================] - 0s 70ms/step
# Processing image 28448/131187: /content/sample_data/Test_Images/518UEpuAHiL.jpg
# 1/1 [==============================] - 0s 56ms/step
# Processing image 28449/131187: /content/sample_data/Test_Images/518UEpuAHiL.jpg
# 1/1 [==============================] - 0s 79ms/step
# Processing image 28450/131187: /content/sample_data/Test_Images/518UGWzlMnL.jpg
# 1/1 [==============================] - 0s 70ms/step
# Processing image 28451/131187: /content/sample_data/Test_Images/518UIPRN3pL.jpg
# 1/1 [==============================] - 0s 59ms/step
# Processing image 28452/131187: /content/sample_data/Test_Images/518UNiOLmeL.jpg
# 1/1 [==============================] - 0s 70ms/step
# Error processing image /content/sample_data/Test_Images/518UNiOLmeL.jpg: y contains previously unseen labels: [27]
# Processing image 28453/131187: /content/sample_data/Test_Images/518UWfiMn0L.jpg
# 1/1 [==============================] - 0s 71ms/step
# Processing image 28454/131187: /content/sample_data/Test_Images/518UWfiMn0L.jpg
# 1/1 [==============================] - 0s 71ms/step
# Processing image 28455/131187: /content/sample_data/Test_Images/518UWfiMn0L.jpg
# 1/1 [==============================] - 0s 57ms/step
# Processing image 28456/131187: /content/sample_data/Test_Images/518Upc9w3aL.jpg
# 1/1 [==============================] - 0s 79ms/step
# Processing image 28457/131187: /content/sample_data/Test_Images/518Upc9w3aL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28458/131187: /content/sample_data/Test_Images/518Upc9w3aL.jpg
# 1/1 [==============================] - 0s 60ms/step
# Processing image 28459/131187: /content/sample_data/Test_Images/518Uq6gzUGL.jpg
# 1/1 [==============================] - 0s 55ms/step
# Processing image 28460/131187: /content/sample_data/Test_Images/518UvkQCOxL.jpg
# 1/1 [==============================] - 0s 48ms/step
# Processing image 28461/131187: /content/sample_data/Test_Images/518UvkQCOxL.jpg
# 1/1 [==============================] - 0s 66ms/step
# Processing image 28462/131187: /content/sample_data/Test_Images/518V0sco+NL.jpg
# 1/1 [==============================] - 0s 80ms/step
# Processing image 28463/131187: /content/sample_data/Test_Images/518V2-ZkRUL.jpg
# 1/1 [==============================] - 0s 82ms/step
# Processing image 28464/131187: /content/sample_data/Test_Images/518V2-ZkRUL.jpg
# 1/1 [==============================] - 0s 76ms/step
# Processing image 28465/131187: /content/sample_data/Test_Images/518V5EKc9dL.jpg
# 1/1 [==============================] - 0s 48ms/step
# Processing image 28466/131187: /content/sample_data/Test_Images/518VBvrI7BS.jpg
# 1/1 [==============================] - 0s 59ms/step
# Processing image 28467/131187: /content/sample_data/Test_Images/518VDDcrVIL.jpg
# 1/1 [==============================] - 0s 83ms/step
# Processing image 28468/131187: /content/sample_data/Test_Images/518VJad8fHL.jpg
# 1/1 [==============================] - 0s 68ms/step
# Processing image 28469/131187: /content/sample_data/Test_Images/518VNeM+BsL.jpg
# 1/1 [==============================] - 0s 78ms/step
# Processing image 28470/131187: /content/sample_data/Test_Images/518VNeM+BsL.jpg
# 1/1 [==============================] - 0s 72ms/step
# Processing image 28471/131187: /content/sample_data/Test_Images/518VWKMoUEL.jpg
# 1/1 [==============================] - 0s 65ms/step
# Error processing image /content/sample_data/Test_Images/518VWKMoUEL.jpg: y contains previously unseen labels: [40]
# Processing image 28472/131187: /content/sample_data/Test_Images/518VYrf6TgL.jpg
# 1/1 [==============================] - 0s 69ms/step
# Processing image 28473/131187: /content/sample_data/Test_Images/518Vcv3sI2S.jpg
# 1/1 [==============================] - 0s 49ms/step
# Processing image 28474/131187: /content/sample_data/Test_Images/518Vjs-UpZL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28475/131187: /content/sample_data/Test_Images/518VkqI2wGS.jpg
# 1/1 [==============================] - 0s 47ms/step
# Processing image 28476/131187: /content/sample_data/Test_Images/518VkqI2wGS.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28477/131187: /content/sample_data/Test_Images/518VnyA7+kL.jpg
# 1/1 [==============================] - 0s 51ms/step
# Processing image 28478/131187: /content/sample_data/Test_Images/518VyOWwVmS.jpg
# 1/1 [==============================] - 0s 63ms/step
# Processing image 28479/131187: /content/sample_data/Test_Images/518Vyq0KhwL.jpg
# 1/1 [==============================] - 0s 45ms/step
# Processing image 28480/131187: /content/sample_data/Test_Images/518W2vtf-5L.jpg
# 1/1 [==============================] - 0s 53ms/step
# Processing image 28481/131187: /content/sample_data/Test_Images/518W4rkVjgL.jpg
# 1/1 [==============================] - 0s 49ms/step
# Error processing image /content/sample_data/Test_Images/518W4rkVjgL.jpg: y contains previously unseen labels: [27]
# Processing image 28482/131187: /content/sample_data/Test_Images/518W9S+-j5L.jpg
# 1/1 [==============================] - 0s 42ms/step
# Error processing image /content/sample_data/Test_Images/518W9S+-j5L.jpg: y contains previously unseen labels: [42]
# Processing image 28483/131187: /content/sample_data/Test_Images/518WGQ97cOL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28484/131187: /content/sample_data/Test_Images/518WGQ97cOL.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 28485/131187: /content/sample_data/Test_Images/518WV9H+7iL.jpg
# 1/1 [==============================] - 0s 37ms/step
# Processing image 28486/131187: /content/sample_data/Test_Images/518WWvXgr+L.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28487/131187: /content/sample_data/Test_Images/518WWvXgr+L.jpg
# 1/1 [==============================] - 0s 60ms/step
# Processing image 28488/131187: /content/sample_data/Test_Images/518WZ0ALH1L.jpg
# 1/1 [==============================] - 0s 35ms/step
# Processing image 28489/131187: /content/sample_data/Test_Images/518WZ0ALH1L.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28490/131187: /content/sample_data/Test_Images/518Wb8iJJOS.jpg
# 1/1 [==============================] - 0s 33ms/step
# Processing image 28491/131187: /content/sample_data/Test_Images/518WhHGqyKL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Error processing image /content/sample_data/Test_Images/518WhHGqyKL.jpg: y contains previously unseen labels: [44]
# Processing image 28492/131187: /content/sample_data/Test_Images/518Wnx-slbL.jpg
# 1/1 [==============================] - 0s 43ms/step
# Error processing image /content/sample_data/Test_Images/518Wnx-slbL.jpg: y contains previously unseen labels: [28]
# Processing image 28493/131187: /content/sample_data/Test_Images/518X+3ol2fS.jpg
# 1/1 [==============================] - 0s 35ms/step
# Error processing image /content/sample_data/Test_Images/518X+3ol2fS.jpg: y contains previously unseen labels: [27]
# Processing image 28494/131187: /content/sample_data/Test_Images/518X07KvSHL.jpg
# 1/1 [==============================] - 0s 35ms/step
# Processing image 28495/131187: /content/sample_data/Test_Images/518X07KvSHL.jpg
# 1/1 [==============================] - 0s 34ms/step
# Processing image 28496/131187: /content/sample_data/Test_Images/518X983qwSS.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28497/131187: /content/sample_data/Test_Images/518X983qwSS.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 28498/131187: /content/sample_data/Test_Images/518XI8uMSeL.jpg
# 1/1 [==============================] - 0s 45ms/step
# Processing image 28499/131187: /content/sample_data/Test_Images/518XI8uMSeL.jpg
# 1/1 [==============================] - 0s 47ms/step
# Processing image 28500/131187: /content/sample_data/Test_Images/518XME-TN-L.jpg
# 1/1 [==============================] - 0s 51ms/step
# Error processing image /content/sample_data/Test_Images/518XME-TN-L.jpg: y contains previously unseen labels: [31]
# Processing image 28501/131187: /content/sample_data/Test_Images/518XPHcgVcL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 28502/131187: /content/sample_data/Test_Images/518XQHT6ZKL.jpg
# 1/1 [==============================] - 0s 36ms/step
# Error processing image /content/sample_data/Test_Images/518XQHT6ZKL.jpg: y contains previously unseen labels: [27]
# Processing image 28503/131187: /content/sample_data/Test_Images/518XQHT6ZKL.jpg
# 1/1 [==============================] - 0s 45ms/step
# Error processing image /content/sample_data/Test_Images/518XQHT6ZKL.jpg: y contains previously unseen labels: [27]
# Processing image 28504/131187: /content/sample_data/Test_Images/518XdHTVgiL.jpg
# 1/1 [==============================] - 0s 41ms/step
# Error processing image /content/sample_data/Test_Images/518XdHTVgiL.jpg: y contains previously unseen labels: [27]
# Processing image 28505/131187: /content/sample_data/Test_Images/518XdstoQWL.jpg
# 1/1 [==============================] - 0s 38ms/step
# Error processing image /content/sample_data/Test_Images/518XdstoQWL.jpg: y contains previously unseen labels: [30]
# Processing image 28506/131187: /content/sample_data/Test_Images/518XedsFdML.jpg
# 1/1 [==============================] - 0s 55ms/step
# Processing image 28507/131187: /content/sample_data/Test_Images/518XedsFdML.jpg
# 1/1 [==============================] - 0s 63ms/step
# Processing image 28508/131187: /content/sample_data/Test_Images/518XpqDa0NL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28509/131187: /content/sample_data/Test_Images/518XqJnvPBL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Error processing image /content/sample_data/Test_Images/518XqJnvPBL.jpg: y contains previously unseen labels: [40]
# Processing image 28510/131187: /content/sample_data/Test_Images/518XqJnvPBL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Error processing image /content/sample_data/Test_Images/518XqJnvPBL.jpg: y contains previously unseen labels: [40]
# Processing image 28511/131187: /content/sample_data/Test_Images/518XqK8kKHL.jpg
# 1/1 [==============================] - 0s 34ms/step
# Processing image 28512/131187: /content/sample_data/Test_Images/518XqK8kKHL.jpg
# 1/1 [==============================] - 0s 37ms/step
# Processing image 28513/131187: /content/sample_data/Test_Images/518Xs2tRF5S.jpg
# 1/1 [==============================] - 0s 49ms/step
# Error processing image /content/sample_data/Test_Images/518Xs2tRF5S.jpg: y contains previously unseen labels: [26]
# Processing image 28514/131187: /content/sample_data/Test_Images/518Xs2tRF5S.jpg
# 1/1 [==============================] - 0s 54ms/step
# Error processing image /content/sample_data/Test_Images/518Xs2tRF5S.jpg: y contains previously unseen labels: [26]
# Processing image 28515/131187: /content/sample_data/Test_Images/518Xs2tRF5S.jpg
# 1/1 [==============================] - 0s 47ms/step
# Error processing image /content/sample_data/Test_Images/518Xs2tRF5S.jpg: y contains previously unseen labels: [26]
# Processing image 28516/131187: /content/sample_data/Test_Images/518XuSARxhL.jpg
# 1/1 [==============================] - 0s 47ms/step
# Processing image 28517/131187: /content/sample_data/Test_Images/518Xur6ZdhL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 28518/131187: /content/sample_data/Test_Images/518Xur6ZdhL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 28519/131187: /content/sample_data/Test_Images/518XvE0cQnL.jpg
# 1/1 [==============================] - 0s 37ms/step
# Processing image 28520/131187: /content/sample_data/Test_Images/518XvulEDBL.jpg
# 1/1 [==============================] - 0s 61ms/step
# Processing image 28521/131187: /content/sample_data/Test_Images/518YFgKMb2L.jpg
# 1/1 [==============================] - 0s 34ms/step
# Error processing image /content/sample_data/Test_Images/518YFgKMb2L.jpg: y contains previously unseen labels: [27]
# Processing image 28522/131187: /content/sample_data/Test_Images/518YOiq2mZL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28523/131187: /content/sample_data/Test_Images/518YVrxOCgL.jpg
# 1/1 [==============================] - 0s 33ms/step
# Processing image 28524/131187: /content/sample_data/Test_Images/518YVrxOCgL.jpg
# 1/1 [==============================] - 0s 37ms/step
# Processing image 28525/131187: /content/sample_data/Test_Images/518YqU2SylL.jpg
# 1/1 [==============================] - 0s 35ms/step
# Error processing image /content/sample_data/Test_Images/518YqU2SylL.jpg: y contains previously unseen labels: [39]
# Processing image 28526/131187: /content/sample_data/Test_Images/518YzIOsLUL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28527/131187: /content/sample_data/Test_Images/518YzlMJzAL.jpg
# 1/1 [==============================] - 0s 52ms/step
# Error processing image /content/sample_data/Test_Images/518YzlMJzAL.jpg: y contains previously unseen labels: [28]
# Processing image 28528/131187: /content/sample_data/Test_Images/518YzlMJzAL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Error processing image /content/sample_data/Test_Images/518YzlMJzAL.jpg: y contains previously unseen labels: [28]
# Processing image 28529/131187: /content/sample_data/Test_Images/518YzlMJzAL.jpg
# 1/1 [==============================] - 0s 38ms/step
# Error processing image /content/sample_data/Test_Images/518YzlMJzAL.jpg: y contains previously unseen labels: [28]
# Processing image 28530/131187: /content/sample_data/Test_Images/518Z+7AgpkL.jpg
# 1/1 [==============================] - 0s 33ms/step
# Error processing image /content/sample_data/Test_Images/518Z+7AgpkL.jpg: y contains previously unseen labels: [28]
# Processing image 28531/131187: /content/sample_data/Test_Images/518Z0T69FFS.jpg
# 1/1 [==============================] - 0s 38ms/step
# Processing image 28532/131187: /content/sample_data/Test_Images/518Z1cgyyHL.jpg
# 1/1 [==============================] - 0s 41ms/step
# Processing image 28533/131187: /content/sample_data/Test_Images/518ZFQdTPuL.jpg
# 1/1 [==============================] - 0s 50ms/step
# Processing image 28534/131187: /content/sample_data/Test_Images/518ZFQdTPuL.jpg
# 1/1 [==============================] - 0s 52ms/step
# Processing image 28535/131187: /content/sample_data/Test_Images/518ZH-Ij0AL.jpg
# 1/1 [==============================] - 0s 35ms/step
# Processing image 28536/131187: /content/sample_data/Test_Images/518ZH-Ij0AL.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 28537/131187: /content/sample_data/Test_Images/518Zdkux8NL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28538/131187: /content/sample_data/Test_Images/518ZgL32z0L.jpg
# 1/1 [==============================] - 0s 61ms/step
# Processing image 28539/131187: /content/sample_data/Test_Images/518Zp7vgxxL.jpg
# 1/1 [==============================] - 0s 73ms/step
# Error processing image /content/sample_data/Test_Images/518Zp7vgxxL.jpg: y contains previously unseen labels: [26]
# Processing image 28540/131187: /content/sample_data/Test_Images/518Zpc69hxL.jpg
# 1/1 [==============================] - 0s 73ms/step
# Processing image 28541/131187: /content/sample_data/Test_Images/518Zpc69hxL.jpg
# 1/1 [==============================] - 0s 56ms/step
# Processing image 28542/131187: /content/sample_data/Test_Images/518ZwikSkYL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Processing image 28543/131187: /content/sample_data/Test_Images/518ZwikSkYL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28544/131187: /content/sample_data/Test_Images/518a-YksPOL.jpg
# 1/1 [==============================] - 0s 77ms/step
# Error processing image /content/sample_data/Test_Images/518a-YksPOL.jpg: y contains previously unseen labels: [28]
# Processing image 28545/131187: /content/sample_data/Test_Images/518a-YksPOL.jpg
# 1/1 [==============================] - 0s 55ms/step
# Error processing image /content/sample_data/Test_Images/518a-YksPOL.jpg: y contains previously unseen labels: [28]
# Processing image 28546/131187: /content/sample_data/Test_Images/518a-YksPOL.jpg
# 1/1 [==============================] - 0s 62ms/step
# Error processing image /content/sample_data/Test_Images/518a-YksPOL.jpg: y contains previously unseen labels: [28]
# Processing image 28547/131187: /content/sample_data/Test_Images/518a31s0HXS.jpg
# 1/1 [==============================] - 0s 73ms/step
# Processing image 28548/131187: /content/sample_data/Test_Images/518a31s0HXS.jpg
# 1/1 [==============================] - 0s 51ms/step
# Processing image 28549/131187: /content/sample_data/Test_Images/518a8UpEMxS.jpg
# 1/1 [==============================] - 0s 73ms/step
# Processing image 28550/131187: /content/sample_data/Test_Images/518a8UpEMxS.jpg
# 1/1 [==============================] - 0s 70ms/step
# Processing image 28551/131187: /content/sample_data/Test_Images/518aK5eoufL.jpg
# 1/1 [==============================] - 0s 54ms/step
# Processing image 28552/131187: /content/sample_data/Test_Images/518aLs5AmdL.jpg
# 1/1 [==============================] - 0s 47ms/step
# Processing image 28553/131187: /content/sample_data/Test_Images/518aTXZwbgL.jpg
# 1/1 [==============================] - 0s 64ms/step
# Processing image 28554/131187: /content/sample_data/Test_Images/518aVP0PBXL.jpg
# 1/1 [==============================] - 0s 74ms/step
# Processing image 28555/131187: /content/sample_data/Test_Images/518aVP0PBXL.jpg
# 1/1 [==============================] - 0s 72ms/step
# Processing image 28556/131187: /content/sample_data/Test_Images/518aVexBEHL.jpg
# 1/1 [==============================] - 0s 53ms/step
# Processing image 28557/131187: /content/sample_data/Test_Images/518adk+D2bL.jpg
# 1/1 [==============================] - 0s 68ms/step
# Processing image 28558/131187: /content/sample_data/Test_Images/518akH3EPQS.jpg
# 1/1 [==============================] - 0s 61ms/step
# Error processing image /content/sample_data/Test_Images/518akH3EPQS.jpg: y contains previously unseen labels: [25]
# Processing image 28559/131187: /content/sample_data/Test_Images/518akH3EPQS.jpg
# 1/1 [==============================] - 0s 64ms/step
# Error processing image /content/sample_data/Test_Images/518akH3EPQS.jpg: y contains previously unseen labels: [25]
# Processing image 28560/131187: /content/sample_data/Test_Images/518av8KaTdL.jpg
# 1/1 [==============================] - 0s 83ms/step
# Processing image 28561/131187: /content/sample_data/Test_Images/518b4-yzDAL.jpg
# 1/1 [==============================] - 0s 68ms/step
# Processing image 28562/131187: /content/sample_data/Test_Images/518bGX++ByL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28563/131187: /content/sample_data/Test_Images/518bI0fSFLL.jpg
# 1/1 [==============================] - 0s 52ms/step
# Processing image 28564/131187: /content/sample_data/Test_Images/518bI0fSFLL.jpg
# 1/1 [==============================] - 0s 70ms/step
# Processing image 28565/131187: /content/sample_data/Test_Images/518bQbS9crL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28566/131187: /content/sample_data/Test_Images/518bQbS9crL.jpg
# 1/1 [==============================] - 0s 105ms/step
# Processing image 28567/131187: /content/sample_data/Test_Images/518bQbS9crL.jpg
# 1/1 [==============================] - 0s 53ms/step
# Processing image 28568/131187: /content/sample_data/Test_Images/518bQsdO+fL.jpg
# 1/1 [==============================] - 0s 91ms/step
# Processing image 28569/131187: /content/sample_data/Test_Images/518bSPJcgKL.jpg
# 1/1 [==============================] - 0s 57ms/step
# Processing image 28570/131187: /content/sample_data/Test_Images/518bSPJcgKL.jpg
# 1/1 [==============================] - 0s 74ms/step
# Processing image 28571/131187: /content/sample_data/Test_Images/518bSPJcgKL.jpg
# 1/1 [==============================] - 0s 63ms/step
# Processing image 28572/131187: /content/sample_data/Test_Images/518bWp+ozOL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28573/131187: /content/sample_data/Test_Images/518btbUg43L.jpg
# 1/1 [==============================] - 0s 52ms/step
# Processing image 28574/131187: /content/sample_data/Test_Images/518bvNvlvyL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Processing image 28575/131187: /content/sample_data/Test_Images/518bvNvlvyL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28576/131187: /content/sample_data/Test_Images/518bvNvlvyL.jpg
# 1/1 [==============================] - 0s 47ms/step
# Processing image 28577/131187: /content/sample_data/Test_Images/518bw9fg9WL.jpg
# 1/1 [==============================] - 0s 78ms/step
# Processing image 28578/131187: /content/sample_data/Test_Images/518c7XiVSFL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28579/131187: /content/sample_data/Test_Images/518c8A50UGL.jpg
# 1/1 [==============================] - 0s 57ms/step
# Processing image 28580/131187: /content/sample_data/Test_Images/518cJ1eoP5L.jpg
# 1/1 [==============================] - 0s 43ms/step
# Error processing image /content/sample_data/Test_Images/518cJ1eoP5L.jpg: y contains previously unseen labels: [39]
# Processing image 28581/131187: /content/sample_data/Test_Images/518cMDJ68OL.jpg
# 1/1 [==============================] - 0s 43ms/step
# Error processing image /content/sample_data/Test_Images/518cMDJ68OL.jpg: y contains previously unseen labels: [39]
# Processing image 28582/131187: /content/sample_data/Test_Images/518cNGP3Y2L.jpg
# 1/1 [==============================] - 0s 41ms/step
# Processing image 28583/131187: /content/sample_data/Test_Images/518cR4d+EgL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28584/131187: /content/sample_data/Test_Images/518cR4d+EgL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28585/131187: /content/sample_data/Test_Images/518cR4d+EgL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 28586/131187: /content/sample_data/Test_Images/518cTYINYeL.jpg
# 1/1 [==============================] - 0s 35ms/step
# Processing image 28587/131187: /content/sample_data/Test_Images/518cXHL2eYL.jpg
# 1/1 [==============================] - 0s 34ms/step
# Processing image 28588/131187: /content/sample_data/Test_Images/518cjag1d2L.jpg
# 1/1 [==============================] - 0s 37ms/step
# Error processing image /content/sample_data/Test_Images/518cjag1d2L.jpg: y contains previously unseen labels: [42]
# Processing image 28589/131187: /content/sample_data/Test_Images/518cjag1d2L.jpg
# 1/1 [==============================] - 0s 36ms/step
# Error processing image /content/sample_data/Test_Images/518cjag1d2L.jpg: y contains previously unseen labels: [42]
# Processing image 28590/131187: /content/sample_data/Test_Images/518cl2L7znL.jpg
# 1/1 [==============================] - 0s 48ms/step
# Processing image 28591/131187: /content/sample_data/Test_Images/518cojAIfVL.jpg
# 1/1 [==============================] - 0s 37ms/step
# Processing image 28592/131187: /content/sample_data/Test_Images/518cojAIfVL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 28593/131187: /content/sample_data/Test_Images/518cojAIfVL.jpg
# 1/1 [==============================] - 0s 34ms/step
# Processing image 28594/131187: /content/sample_data/Test_Images/518cu4denvL.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 28595/131187: /content/sample_data/Test_Images/518cxArxFgL.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 28596/131187: /content/sample_data/Test_Images/518cyFdHgFL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Error processing image /content/sample_data/Test_Images/518cyFdHgFL.jpg: y contains previously unseen labels: [28]
# Processing image 28597/131187: /content/sample_data/Test_Images/518cyFdHgFL.jpg
# 1/1 [==============================] - 0s 51ms/step
# Error processing image /content/sample_data/Test_Images/518cyFdHgFL.jpg: y contains previously unseen labels: [28]
# Processing image 28598/131187: /content/sample_data/Test_Images/518d4mfIPVL.jpg
# 1/1 [==============================] - 0s 43ms/step
# Processing image 28599/131187: /content/sample_data/Test_Images/518d7NwbqZS.jpg
# 1/1 [==============================] - 0s 43ms/step
# Processing image 28600/131187: /content/sample_data/Test_Images/518d7NwbqZS.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28601/131187: /content/sample_data/Test_Images/518d7fOYNuL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Processing image 28602/131187: /content/sample_data/Test_Images/518d8AlNWzL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Error processing image /content/sample_data/Test_Images/518d8AlNWzL.jpg: y contains previously unseen labels: [39]
# Processing image 28603/131187: /content/sample_data/Test_Images/518d8AlNWzL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Error processing image /content/sample_data/Test_Images/518d8AlNWzL.jpg: y contains previously unseen labels: [39]
# Processing image 28604/131187: /content/sample_data/Test_Images/518d8AlNWzL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Error processing image /content/sample_data/Test_Images/518d8AlNWzL.jpg: y contains previously unseen labels: [39]
# Processing image 28605/131187: /content/sample_data/Test_Images/518dEP3UJkL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28606/131187: /content/sample_data/Test_Images/518dEP3UJkL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28607/131187: /content/sample_data/Test_Images/518dHPkhVXL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28608/131187: /content/sample_data/Test_Images/518dLlqvBiL.jpg
# 1/1 [==============================] - 0s 41ms/step
# Processing image 28609/131187: /content/sample_data/Test_Images/518dg4MI2GS.jpg
# 1/1 [==============================] - 0s 44ms/step
# Processing image 28610/131187: /content/sample_data/Test_Images/518dg4MI2GS.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28611/131187: /content/sample_data/Test_Images/518dhbYNPwL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 28612/131187: /content/sample_data/Test_Images/518dhbYNPwL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 28613/131187: /content/sample_data/Test_Images/518dx6LvpoL.jpg
# 1/1 [==============================] - 0s 33ms/step
# Error processing image /content/sample_data/Test_Images/518dx6LvpoL.jpg: y contains previously unseen labels: [27]
# Processing image 28614/131187: /content/sample_data/Test_Images/518e-G-qpkL.jpg
# 1/1 [==============================] - 0s 33ms/step
# Error processing image /content/sample_data/Test_Images/518e-G-qpkL.jpg: y contains previously unseen labels: [27]
# Processing image 28615/131187: /content/sample_data/Test_Images/518e-G-qpkL.jpg
# 1/1 [==============================] - 0s 38ms/step
# Error processing image /content/sample_data/Test_Images/518e-G-qpkL.jpg: y contains previously unseen labels: [27]
# Processing image 28616/131187: /content/sample_data/Test_Images/518e0766uXL.jpg
# 1/1 [==============================] - 0s 41ms/step
# Processing image 28617/131187: /content/sample_data/Test_Images/518e0766uXL.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 28618/131187: /content/sample_data/Test_Images/518e0766uXL.jpg
# 1/1 [==============================] - 0s 59ms/step
# ...
# Processing image 30439/131187: /content/sample_data/Test_Images/51AgKV+rKdL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 30440/131187: /content/sample_data/Test_Images/51AgKV+rKdL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 30441/131187: /content/sample_data/Test_Images/51Agj0qbFuL.jpg
# 1/1 [==============================] - 0s 51ms/step
# Error processing image /content/sample_data/Test_Images/51Agj0qbFuL.jpg: y contains previously unseen labels: [27]
# Processing image 30442/131187: /content/sample_data/Test_Images/51Agj0qbFuL.jpg
# 1/1 [==============================] - 0s 35ms/step
# Error processing image /content/sample_data/Test_Images/51Agj0qbFuL.jpg: y contains previously unseen labels: [27]
# Processing image 30443/131187: /content/sample_data/Test_Images/51Ah0IgmEkL.jpg
# 1/1 [==============================] - 0s 32ms/step
# Processing image 30444/131187: /content/sample_data/Test_Images/51AhC1xdXUL.jpg
# 1/1 [==============================] - 0s 45ms/step
# Processing image 30445/131187: /content/sample_data/Test_Images/51AhDXhKHVL.jpg
# 1/1 [==============================] - 0s 33ms/step
# Processing image 30446/131187: /content/sample_data/Test_Images/51AhDXhKHVL.jpg
# 1/1 [==============================] - 0s 34ms/step
# Processing image 30447/131187: /content/sample_data/Test_Images/51AhDXhKHVL.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 30448/131187: /content/sample_data/Test_Images/51AhGxR96RL.jpg
# 1/1 [==============================] - 0s 61ms/step
# Processing image 30449/131187: /content/sample_data/Test_Images/51AhNf4JfCL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 30450/131187: /content/sample_data/Test_Images/51AhNf4JfCL.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 30451/131187: /content/sample_data/Test_Images/51Ahi3c7vwL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 30452/131187: /content/sample_data/Test_Images/51Ahjrn07gL.jpg
# 1/1 [==============================] - 0s 54ms/step
# Error processing image /content/sample_data/Test_Images/51Ahjrn07gL.jpg: y contains previously unseen labels: [27]
# Processing image 30453/131187: /content/sample_data/Test_Images/51Ahjrn07gL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Error processing image /content/sample_data/Test_Images/51Ahjrn07gL.jpg: y contains previously unseen labels: [27]
# Processing image 30454/131187: /content/sample_data/Test_Images/51Ahva3CuFL.jpg
# 1/1 [==============================] - 0s 53ms/step
# Error processing image /content/sample_data/Test_Images/51Ahva3CuFL.jpg: y contains previously unseen labels: [27]
# Processing image 30455/131187: /content/sample_data/Test_Images/51Ai6GXsB4L.jpg
# 1/1 [==============================] - 0s 77ms/step
# Processing image 30456/131187: /content/sample_data/Test_Images/51Ai8yMkNcL.jpg
# 1/1 [==============================] - 0s 48ms/step
# Processing image 30457/131187: /content/sample_data/Test_Images/51Ai8yMkNcL.jpg
# 1/1 [==============================] - 0s 55ms/step
# Processing image 30458/131187: /content/sample_data/Test_Images/51AiKRQBMDL.jpg
# 1/1 [==============================] - 0s 61ms/step
# Processing image 30459/131187: /content/sample_data/Test_Images/51AiKRQBMDL.jpg
# 1/1 [==============================] - 0s 45ms/step
# Processing image 30460/131187: /content/sample_data/Test_Images/51AiKRQBMDL.jpg
# 1/1 [==============================] - 0s 60ms/step
# Processing image 30461/131187: /content/sample_data/Test_Images/51AiKRnhiIL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 30462/131187: /content/sample_data/Test_Images/51AiKRnhiIL.jpg
# 1/1 [==============================] - 0s 53ms/step
# Processing image 30463/131187: /content/sample_data/Test_Images/51AiUqtx3VL.jpg
# 1/1 [==============================] - 0s 59ms/step
# Error processing image /content/sample_data/Test_Images/51AiUqtx3VL.jpg: y contains previously unseen labels: [27]
# Processing image 30464/131187: /content/sample_data/Test_Images/51AiUqtx3VL.jpg
# 1/1 [==============================] - 0s 62ms/step
# Error processing image /content/sample_data/Test_Images/51AiUqtx3VL.jpg: y contains previously unseen labels: [27]
# Processing image 30465/131187: /content/sample_data/Test_Images/51AiZhyyreL.jpg
# 1/1 [==============================] - 0s 65ms/step
# Processing image 30466/131187: /content/sample_data/Test_Images/51AixAQR7yL.jpg
# 1/1 [==============================] - 0s 65ms/step
# Processing image 30467/131187: /content/sample_data/Test_Images/51AixAQR7yL.jpg
# 1/1 [==============================] - 0s 82ms/step
# Processing image 30468/131187: /content/sample_data/Test_Images/51AixAQR7yL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 30469/131187: /content/sample_data/Test_Images/51Aiz2A3m7L.jpg
# 1/1 [==============================] - 0s 51ms/step
# Processing image 30470/131187: /content/sample_data/Test_Images/51Aj4Su0OiL.jpg
# 1/1 [==============================] - 0s 63ms/step
# Error processing image /content/sample_data/Test_Images/51Aj4Su0OiL.jpg: y contains previously unseen labels: [28]
# Processing image 30471/131187: /content/sample_data/Test_Images/51Aj4o1-LDL.jpg
# 1/1 [==============================] - 0s 66ms/step
# Processing image 30472/131187: /content/sample_data/Test_Images/51Aj4o1-LDL.jpg
# 1/1 [==============================] - 0s 84ms/step
# Processing image 30473/131187: /content/sample_data/Test_Images/51AjCf7517L.jpg
# 1/1 [==============================] - 0s 55ms/step
# Error processing image /content/sample_data/Test_Images/51AjCf7517L.jpg: y contains previously unseen labels: [28]
# Processing image 30474/131187: /content/sample_data/Test_Images/51AjLuaU1OL.jpg
# 1/1 [==============================] - 0s 45ms/step
# Error processing image /content/sample_data/Test_Images/51AjLuaU1OL.jpg: y contains previously unseen labels: [27]
# Processing image 30475/131187: /content/sample_data/Test_Images/51AjPmK8HuL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 30476/131187: /content/sample_data/Test_Images/51AjTsrlnDS.jpg
# 1/1 [==============================] - 0s 76ms/step
# Error processing image /content/sample_data/Test_Images/51AjTsrlnDS.jpg: y contains previously unseen labels: [29]
# Processing image 30477/131187: /content/sample_data/Test_Images/51AjV9fchhL.jpg
# 1/1 [==============================] - 0s 56ms/step
# Error processing image /content/sample_data/Test_Images/51AjV9fchhL.jpg: y contains previously unseen labels: [26]
# Processing image 30478/131187: /content/sample_data/Test_Images/51Ajf5r4i1L.jpg
# 1/1 [==============================] - 0s 77ms/step
# Error processing image /content/sample_data/Test_Images/51Ajf5r4i1L.jpg: y contains previously unseen labels: [40]
# Processing image 30479/131187: /content/sample_data/Test_Images/51AjfrYk0VL.jpg
# 1/1 [==============================] - 0s 56ms/step
# Processing image 30480/131187: /content/sample_data/Test_Images/51AjfrYk0VL.jpg
# 1/1 [==============================] - 0s 60ms/step
# Processing image 30481/131187: /content/sample_data/Test_Images/51AjqLkpluL.jpg
# 1/1 [==============================] - 0s 54ms/step
# Processing image 30482/131187: /content/sample_data/Test_Images/51AjyX5KT1L.jpg
# 1/1 [==============================] - 0s 67ms/step
# Processing image 30483/131187: /content/sample_data/Test_Images/51AjyX5KT1L.jpg
# 1/1 [==============================] - 0s 41ms/step
# Processing image 30484/131187: /content/sample_data/Test_Images/51Ak0ziHUSS.jpg
# 1/1 [==============================] - 0s 47ms/step
# Processing image 30485/131187: /content/sample_data/Test_Images/51AkA5kGhgL.jpg
# 1/1 [==============================] - 0s 77ms/step
# Processing image 30486/131187: /content/sample_data/Test_Images/51AkA5kGhgL.jpg
# 1/1 [==============================] - 0s 68ms/step
# Processing image 30487/131187: /content/sample_data/Test_Images/51AkEaKfZoS.jpg
# 1/1 [==============================] - 0s 43ms/step
# Processing image 30488/131187: /content/sample_data/Test_Images/51AkLhIFF6L.jpg
# 1/1 [==============================] - 0s 59ms/step
# Error processing image /content/sample_data/Test_Images/51AkLhIFF6L.jpg: y contains previously unseen labels: [27]
# Processing image 30489/131187: /content/sample_data/Test_Images/51AkLhIFF6L.jpg
# 1/1 [==============================] - 0s 51ms/step
# Error processing image /content/sample_data/Test_Images/51AkLhIFF6L.jpg: y contains previously unseen labels: [27]
# Processing image 30490/131187: /content/sample_data/Test_Images/51AkLhIFF6L.jpg
# 1/1 [==============================] - 0s 42ms/step
# Error processing image /content/sample_data/Test_Images/51AkLhIFF6L.jpg: y contains previously unseen labels: [27]
# Processing image 30491/131187: /content/sample_data/Test_Images/51AkO7RtRML.jpg
# 1/1 [==============================] - 0s 43ms/step
# Error processing image /content/sample_data/Test_Images/51AkO7RtRML.jpg: y contains previously unseen labels: [31]
# Processing image 30492/131187: /content/sample_data/Test_Images/51AkUi-JPIL.jpg
# 1/1 [==============================] - 0s 68ms/step
# Processing image 30493/131187: /content/sample_data/Test_Images/51AkUi-JPIL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 30494/131187: /content/sample_data/Test_Images/51AkpaEfDNL.jpg
# 1/1 [==============================] - 0s 43ms/step
# Error processing image /content/sample_data/Test_Images/51AkpaEfDNL.jpg: y contains previously unseen labels: [40]
# Processing image 30495/131187: /content/sample_data/Test_Images/51AkpaEfDNL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Error processing image /content/sample_data/Test_Images/51AkpaEfDNL.jpg: y contains previously unseen labels: [40]
# Processing image 30496/131187: /content/sample_data/Test_Images/51Akr3-IDpL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Error processing image /content/sample_data/Test_Images/51Akr3-IDpL.jpg: y contains previously unseen labels: [28]
# Processing image 30497/131187: /content/sample_data/Test_Images/51Akr3-IDpL.jpg
# 1/1 [==============================] - 0s 41ms/step
# Error processing image /content/sample_data/Test_Images/51Akr3-IDpL.jpg: y contains previously unseen labels: [28]
# Processing image 30498/131187: /content/sample_data/Test_Images/51Aky0OPlZL.jpg
# 1/1 [==============================] - 0s 40ms/step
# Processing image 30499/131187: /content/sample_data/Test_Images/51Aky0OPlZL.jpg
# 1/1 [==============================] - 0s 61ms/step
# Processing image 30500/131187: /content/sample_data/Test_Images/51Aky0OPlZL.jpg
# 1/1 [==============================] - 0s 33ms/step
# Processing image 30501/131187: /content/sample_data/Test_Images/51AkziZvNGL.jpg
# 1/1 [==============================] - 0s 34ms/step
# Processing image 30502/131187: /content/sample_data/Test_Images/51Al-cKKG6L.jpg
# 1/1 [==============================] - 0s 42ms/step
# Error processing image /content/sample_data/Test_Images/51Al-cKKG6L.jpg: y contains previously unseen labels: [27]
# Processing image 30503/131187: /content/sample_data/Test_Images/51Al-cKKG6L.jpg
# 1/1 [==============================] - 0s 58ms/step
# Error processing image /content/sample_data/Test_Images/51Al-cKKG6L.jpg: y contains previously unseen labels: [27]
# Processing image 30504/131187: /content/sample_data/Test_Images/51AlDF5VPBL.jpg
# 1/1 [==============================] - 0s 33ms/step
# Processing image 30505/131187: /content/sample_data/Test_Images/51AlInBpPGL.jpg
# 1/1 [==============================] - 0s 33ms/step
# Processing image 30506/131187: /content/sample_data/Test_Images/51AlInBpPGL.jpg
# 1/1 [==============================] - 0s 37ms/step
# Processing image 30507/131187: /content/sample_data/Test_Images/51AlJ-Ul3RL.jpg
# 1/1 [==============================] - 0s 33ms/step
# Processing image 30508/131187: /content/sample_data/Test_Images/51AlU5sjFQL.jpg
# 1/1 [==============================] - 0s 46ms/step
# Processing image 30509/131187: /content/sample_data/Test_Images/51AlU5sjFQL.jpg
# 1/1 [==============================] - 0s 35ms/step
# Processing image 30510/131187: /content/sample_data/Test_Images/51AlZhs7sOL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 30511/131187: /content/sample_data/Test_Images/51AlZhs7sOL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Processing image 30512/131187: /content/sample_data/Test_Images/51AlZhs7sOL.jpg
# 1/1 [==============================] - 0s 45ms/step
# Processing image 30513/131187: /content/sample_data/Test_Images/51AlchqCqLL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 30514/131187: /content/sample_data/Test_Images/51AlmATF6uL.jpg
# 1/1 [==============================] - 0s 38ms/step
# Error processing image /content/sample_data/Test_Images/51AlmATF6uL.jpg: y contains previously unseen labels: [27]
# Processing image 30515/131187: /content/sample_data/Test_Images/51AlmATF6uL.jpg
# 1/1 [==============================] - 0s 51ms/step
# Error processing image /content/sample_data/Test_Images/51AlmATF6uL.jpg: y contains previously unseen labels: [27]
# Processing image 30516/131187: /content/sample_data/Test_Images/51AlmpbxXSL.jpg
# 1/1 [==============================] - 0s 50ms/step
# Processing image 30517/131187: /content/sample_data/Test_Images/51AlpEvSMDL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 30518/131187: /content/sample_data/Test_Images/51AlqvTTY0L.jpg
# 1/1 [==============================] - 0s 32ms/step
# Error processing image /content/sample_data/Test_Images/51AlqvTTY0L.jpg: y contains previously unseen labels: [27]
# Processing image 30519/131187: /content/sample_data/Test_Images/51AlqvTTY0L.jpg
# 1/1 [==============================] - 0s 34ms/step
# Error processing image /content/sample_data/Test_Images/51AlqvTTY0L.jpg: y contains previously unseen labels: [27]
# Processing image 30520/131187: /content/sample_data/Test_Images/51Am-i17OAL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 30521/131187: /content/sample_data/Test_Images/51Am-i17OAL.jpg
# 1/1 [==============================] - 0s 47ms/step
# Processing image 30522/131187: /content/sample_data/Test_Images/51Am0GM60IL.jpg
# 1/1 [==============================] - 0s 44ms/step
# Processing image 30523/131187: /content/sample_data/Test_Images/51AmF9DIJfL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 30524/131187: /content/sample_data/Test_Images/51AmF9DIJfL.jpg
# 1/1 [==============================] - 0s 37ms/step
# Processing image 30525/131187: /content/sample_data/Test_Images/51AmIVC+irL.jpg
# 1/1 [==============================] - 0s 41ms/step
# Processing image 30526/131187: /content/sample_data/Test_Images/51AmIVC+irL.jpg
# 1/1 [==============================] - 0s 39ms/step
# Processing image 30527/131187: /content/sample_data/Test_Images/51AmIVC+irL.jpg
# 1/1 [==============================] - 0s 45ms/step
# Processing image 30528/131187: /content/sample_data/Test_Images/51AmItqT+sL.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 30529/131187: /content/sample_data/Test_Images/51AmaifkCDL.jpg
# 1/1 [==============================] - 0s 35ms/step
# Processing image 30530/131187: /content/sample_data/Test_Images/51AmcgHd1DL.jpg
# 1/1 [==============================] - 0s 52ms/step
# Processing image 30531/131187: /content/sample_data/Test_Images/51AmeFvCHUL.jpg
# 1/1 [==============================] - 0s 36ms/step
# Error processing image /content/sample_data/Test_Images/51AmeFvCHUL.jpg: y contains previously unseen labels: [27]
# Processing image 30532/131187: /content/sample_data/Test_Images/51Amf7l9F8L.jpg
# 1/1 [==============================] - 0s 42ms/step
# Processing image 30533/131187: /content/sample_data/Test_Images/51Amf7l9F8L.jpg
# 1/1 [==============================] - 0s 36ms/step
# Processing image 30534/131187: /content/sample_data/Test_Images/51AmjSJt7OL.jpg
# 1/1 [==============================] - 0s 48ms/step
# Processing image 30535/131187: /content/sample_data/Test_Images/51AmjSJt7OL.jpg

# %%
res = pd.read_csv('/content/sample_data/Prediction/test_predictions.csv')
res.head(100)
